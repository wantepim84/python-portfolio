# %%
pip install pygame
# Out:
# Collecting pygameNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading pygame-2.5.2-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.5.2-cp311-cp311-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.8 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/10.8 MB 3.5 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/10.8 MB 5.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/10.8 MB 7.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.9/10.8 MB 7.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.5/10.8 MB 8.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.2/10.8 MB 9.2 MB/s eta 0:00:01
#    ------------- -------------------------- 3.7/10.8 MB 9.3 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/10.8 MB 9.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.8/10.8 MB 10.0 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.8 MB 10.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.1/10.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------- -------------- 6.8/10.8 MB 10.5 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.8 MB 10.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.8 MB 11.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.3/10.8 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 9.0/10.8 MB 10.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.5/10.8 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.1/10.8 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  10.8/10.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.5.2

# %%
import os
import pygame
import tkinter as tk
from tkinter import filedialog


def play_music():
    selected_song = listbox.get(tk.ACTIVE)
    pygame.mixer.music.load(selected_song)
    pygame.mixer.music.play()

def stop_music():
    pygame.mixer.music.stop()

def load_music():
    folder = filedialog.askdirectory()
    os.chdir(folder)
    songs = [file for file in os.listdir(folder) if file.endswith(".mp3")]
    for song in songs:
        listbox.insert(tk.END, song)

window = tk.Tk()
window.title("MP3 Player")

pygame.init()
pygame.mixer.init()

listbox = tk.Listbox(window, width = 50)
listbox.pack(pady=10)

play_button = tk.Button(window, text="Play", command=play_music)
play_button.pack(pady=5)

stop_button = tk.Button(window, text="Stop", command=stop_music)
stop_button.pack(pady=5)

load_button = tk.Button(window, text="Load Music Folder", command=load_music)
load_button.pack(pady=10)

window.mainloop()

# %%
import os
import pygame
import tkinter as tk
from tkinter import filedialog

def play_music():
    selected_song = listbox.get(tk.ACTIVE)
    pygame.mixer.music.load(selected_song)
    pygame.mixer.music.play()

def stop_music():
    pygame.mixer.music.stop()

def load_music():
    folder = filedialog.askdirectory()
    os.chdir(folder)
    songs = [file for file in os.listdir(folder) if file.endswith(".mp3")]
    listbox.delete(0, tk.END)  # Clear the listbox before inserting new songs
    for song in songs:
        listbox.insert(tk.END, song)

def fast_forward():
    current_pos = pygame.mixer.music.get_pos() // 1000  # Get current position in seconds
    pygame.mixer.music.set_pos(current_pos + 10)  # Fast forward by 10 seconds

def rewind():
    current_pos = pygame.mixer.music.get_pos() // 1000  # Get current position in seconds
    pygame.mixer.music.set_pos(current_pos - 10)  # Rewind by 10 seconds

window = tk.Tk()
window.title("MP3 Player")

pygame.init()
pygame.mixer.init()

listbox = tk.Listbox(window, width=50)
listbox.pack(pady=10)

play_button = tk.Button(window, text="Play", command=play_music)
play_button.pack(pady=5)

stop_button = tk.Button(window, text="Stop", command=stop_music)
stop_button.pack(pady=5)

load_button = tk.Button(window, text="Load Music Folder", command=load_music)
load_button.pack(pady=10)

fast_forward_button = tk.Button(window, text="Fast Forward", command=fast_forward)
fast_forward_button.pack(pady=5)

rewind_button = tk.Button(window, text="Rewind", command=rewind)
rewind_button.pack(pady=5)

window.mainloop()

# %%
import os
import pygame
import tkinter as tk
from tkinter import filedialog

def play_music():
    selected_song = listbox.get(tk.ACTIVE)
    pygame.mixer.music.load(selected_song)
    pygame.mixer.music.play()

def stop_music():
    pygame.mixer.music.stop()

def load_music():
    folder = filedialog.askdirectory()
    os.chdir(folder)
    songs = [file for file in os.listdir(folder) if file.endswith(".mp3")]
    listbox.delete(0, tk.END)
    for song in songs:
        listbox.insert(tk.END, song)

def fast_forward():
    current_pos = pygame.mixer.music.get_pos() // 1000
    new_pos = current_pos + 10
    pygame.mixer.music.rewind()
    pygame.mixer.music.set_pos(new_pos)

def rewind():
    current_pos = pygame.mixer.music.get_pos() // 1000
    new_pos = current_pos - 10
    pygame.mixer.music.rewind()
    pygame.mixer.music.set_pos(new_pos)

window = tk.Tk()
window.title("MP3 Player")

pygame.init()
pygame.mixer.init()

listbox = tk.Listbox(window, width=50, bg='blue', fg='white')
listbox.pack(pady=10)

play_button = tk.Button(window, text="Play", command=play_music)
play_button.pack(pady=5)

stop_button = tk.Button(window, text="Stop", command=stop_music)
stop_button.pack(pady=5)

load_button = tk.Button(window, text="Load Music Folder", command=load_music)
load_button.pack(pady=10)

fast_forward_button = tk.Button(window, text="Fast Forward", command=fast_forward)
fast_forward_button.pack(pady=5)

rewind_button = tk.Button(window, text="Rewind", command=rewind)
rewind_button.pack(pady=5)

window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_23288\3112410214.py", line 16, in load_music
#     os.chdir(folder)
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: ''

# %%
pip install pyaudio
# Out:
# Collecting pyaudio
#   Downloading PyAudio-0.2.14-cp311-cp311-win_amd64.whl.metadata (2.7 kB)
# Downloading PyAudio-0.2.14-cp311-cp311-win_amd64.whl (164 kB)
#    ---------------------------------------- 0.0/164.1 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/164.1 kB ? eta -:--:--
#    -------------- ------------------------ 61.4/164.1 kB 656.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 122.9/164.1 kB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 164.1/164.1 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.14
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import tkinter as tk
from tkinter import filedialog
import pyaudio
import wave

def play_music():
    selected_song = listbox.get(tk.ACTIVE)
    play_audio(selected_song)

def stop_music():
    global stream
    if stream is not None:
        stream.stop_stream()
        stream.close()

def load_music():
    try:
        folder = filedialog.askdirectory()
        
        # Check if the folder selection was canceled
        if not folder:
            print("Folder selection canceled.")
            return
        
        print(f"Selected Folder: {folder}")
        os.chdir(folder)
        print(f"Current Working Directory: {os.getcwd()}")
        
        songs = [file for file in os.listdir(folder) if file.endswith(".mp3")]
        print(f"Songs: {songs}")
        
        listbox.delete(0, tk.END)
        for song in songs:
            listbox.insert(tk.END, song)
    except Exception as e:
        print(f"Error loading music: {e}")


def fast_forward():
    pass  # Implement fast forward functionality if needed

def rewind():
    pass  # Implement rewind functionality if needed

def play_audio(file_path):
    global stream
    chunk = 1024
    wf = wave.open(file_path, 'rb')
    
    p = pyaudio.PyAudio()
    stream = p.open(format=p.get_format_from_width(wf.getsampwidth()),
                    channels=wf.getnchannels(),
                    rate=wf.getframerate(),
                    output=True)
    
    data = wf.readframes(chunk)
    while data:
        stream.write(data)
        data = wf.readframes(chunk)
    
    stream.stop_stream()
    stream.close()
    p.terminate()

window = tk.Tk()
window.title("MP3 Player")

stream = None  # Global variable to store the PyAudio stream

listbox = tk.Listbox(window, width=50)
listbox.pack(pady=10)

play_button = tk.Button(window, text="Play", command=play_music)
play_button.pack(pady=5)

stop_button = tk.Button(window, text="Stop", command=stop_music)
stop_button.pack(pady=5)

load_button = tk.Button(window, text="Load Music Folder", command=load_music)
load_button.pack(pady=10)

fast_forward_button = tk.Button(window, text="Fast Forward", command=fast_forward)
fast_forward_button.pack(pady=5)

rewind_button = tk.Button(window, text="Rewind", command=rewind)
rewind_button.pack(pady=5)

window.mainloop()
# Out:
# Folder selection canceled.
# Selected Folder: C:/Users/w_ant/Music/music
# Current Working Directory: C:\Users\w_ant\Music\music
Walker -  Colorful Flowers (128 kbps).mp3', 'Tom Budin & WHTKD - Bad Vibe (128 kbps).mp3', 'Trippie Redd - I Got Game (Hate is Dead Mixtape) (128 kbps).mp3', 'Trippie Redd - Red Line (Hate is Dead Mixtape) (Official Audio) (128 kbps).mp3', 'Trippie Redd - So Thankful (Hate is Dead Mixtape) (Official Audio) (128 kbps).mp3', 'Vexento - Tevo (128 kbps).mp3', 'VINAI Feat. Anjulie - Into The Fire (128 kbps).mp3', 'Wiz Khalifa - Work Hard Play Hard (Lyrics On Screen) (128 kbps).mp3', 'ytmp3free.cc_mt-eden-dubstep-still-alive-youtubemp3free.org.mp3', '[FREE] Roddy Ricch x Mustard Type Beat Gucci Girl (Prod Gibbo x VITALS) (128 kbps).mp3', '• Trippie Redd - Throw It Up (Legendado_Tradução) (128 kbps).mp3', '𝐀𝐥𝐞𝐱 𝐆 - 𝐓𝐫𝐞𝐞𝐡𝐨𝐮𝐬𝐞 (𝐋𝐲𝐫𝐢𝐜𝐬) (128 kbps).mp3']
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 9, in play_music
#     play_audio(selected_song)
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 49, in play_audio
#     wf = wave.open(file_path, 'rb')
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 631, in open
#     return Wave_read(f)
#            ^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 283, in __init__
#     self.initfp(f)
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 250, in initfp
#     raise Error('file does not start with RIFF id')
# wave.Error: file does not start with RIFF id
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 9, in play_music
#     play_audio(selected_song)
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 49, in play_audio
#     wf = wave.open(file_path, 'rb')
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 631, in open
#     return Wave_read(f)
#            ^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 283, in __init__
#     self.initfp(f)
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 250, in initfp
#     raise Error('file does not start with RIFF id')
# wave.Error: file does not start with RIFF id
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 9, in play_music
#     play_audio(selected_song)
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 49, in play_audio
#     wf = wave.open(file_path, 'rb')
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 631, in open
#     return Wave_read(f)
#            ^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 283, in __init__
#     self.initfp(f)
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 250, in initfp
#     raise Error('file does not start with RIFF id')
# wave.Error: file does not start with RIFF id
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 9, in play_music
#     play_audio(selected_song)
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 49, in play_audio
#     wf = wave.open(file_path, 'rb')
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 631, in open
#     return Wave_read(f)
#            ^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 283, in __init__
#     self.initfp(f)
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 250, in initfp
#     raise Error('file does not start with RIFF id')
# wave.Error: file does not start with RIFF id
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 9, in play_music
#     play_audio(selected_song)
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 49, in play_audio
#     wf = wave.open(file_path, 'rb')
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 631, in open
#     return Wave_read(f)
#            ^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 283, in __init__
#     self.initfp(f)
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 250, in initfp
#     raise Error('file does not start with RIFF id')
# wave.Error: file does not start with RIFF id
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 9, in play_music
#     play_audio(selected_song)
#   File "C:\Users\w_ant\AppData\Local\Temp\ipykernel_32932\2481792111.py", line 49, in play_audio
#     wf = wave.open(file_path, 'rb')
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 631, in open
#     return Wave_read(f)
#            ^^^^^^^^^^^^
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 283, in __init__
#     self.initfp(f)
#   File "C:\Users\w_ant\AppData\Local\Programs\Python\Python311\Lib\wave.py", line 250, in initfp
#     raise Error('file does not start with RIFF id')
# wave.Error: file does not start with RIFF id

# %%
def load_music():
    try:
        folder = filedialog.askdirectory()
        print(f"Selected Folder: {folder}")
        
        os.chdir(folder)
        print(f"Current Working Directory: {os.getcwd()}")
        
        songs = [file for file in os.listdir(folder) if file.endswith(".mp3")]
        print(f"Songs: {songs}")
        
        listbox.delete(0, tk.END)
        for song in songs:
            listbox.insert(tk.END, song)
    except Exception as e:
        print(f"Error loading music: {e}")
